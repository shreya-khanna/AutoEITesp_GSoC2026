# %% [markdown]
# # AutoEIT — Transcription Analysis
# Builds per-recording `summary.json` files, then aggregates them for overall analysis.

# %%
import json
import re
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pathlib import Path

# %% [markdown]
# ## Config

# %%
TRANSCRIBED_ROOT = Path("../../data/transcribed/v1")
VERSIONS = ["version_a", "version_b"]

# %% [markdown]
# ## Build per-recording summaries
# Reads all `item_*.json` files for each recording, computes summary metrics, saves `summary.json`.

# %%
def summarize_item(item_path: Path) -> dict:
    with open(item_path) as f:
        data = json.load(f)

    index = int(re.search(r"item_(\d+)", item_path.stem).group(1))
    text = " ".join(seg["text"].strip() for seg in data["segments"]).strip()

    all_words = [w for seg in data["segments"] for w in seg.get("words", [])]
    word_count = len(all_words)
    mean_word_prob = round(sum(w["prob"] for w in all_words) / word_count, 4) if all_words else None

    return {
        "index": index,
        "duration": data["duration"],
        "language": data["language"],
        "language_probability": data["language_probability"],
        "word_count": word_count,
        "mean_word_prob": mean_word_prob,
        "text": text,
        "empty": word_count == 0 or len(text) < 3,
    }

# %%
def build_recording_summary(recording_dir: Path, version: str) -> dict:
    item_files = sorted(recording_dir.glob("item_*.json"),
                        key=lambda p: int(re.search(r"item_(\d+)", p.stem).group(1)))
    items = [summarize_item(p) for p in item_files]
    return {
        "recording": recording_dir.name,
        "version": version,
        "item_count": len(items),
        "items": items,
    }

# %%
built = 0
skipped = 0

for version in VERSIONS:
    version_dir = TRANSCRIBED_ROOT / version
    if not version_dir.exists():
        print(f"Not found: {version_dir}")
        continue
    for recording_dir in sorted(version_dir.iterdir()):
        if not recording_dir.is_dir():
            continue
        summary_path = recording_dir / "summary.json"
        if summary_path.exists():
            skipped += 1
            continue
        summary = build_recording_summary(recording_dir, version)
        with open(summary_path, "w", encoding="utf-8") as f:
            json.dump(summary, f, ensure_ascii=False, indent=2)
        built += 1

print(f"Built {built} summaries, skipped {skipped} (already exist)")
# Out:
# Built 0 summaries, skipped 205 (already exist)

# %% [markdown]
# ## Load summaries into DataFrames

# %%
recording_rows = []
item_rows = []

for version in VERSIONS:
    version_dir = TRANSCRIBED_ROOT / version
    if not version_dir.exists():
        continue
    for summary_path in sorted(version_dir.glob("*/summary.json")):
        with open(summary_path) as f:
            s = json.load(f)
        recording_rows.append({
            "recording": s["recording"],
            "version": s["version"],
            "item_count": s["item_count"],
            "empty_count": sum(1 for it in s["items"] if it["empty"]),
            "mean_word_prob": round(
                sum(it["mean_word_prob"] for it in s["items"] if it["mean_word_prob"] is not None) /
                max(1, sum(1 for it in s["items"] if it["mean_word_prob"] is not None)), 4
            ),
            "mean_duration": round(sum(it["duration"] for it in s["items"]) / max(1, s["item_count"]), 3),
        })
        for it in s["items"]:
            item_rows.append({
                "recording": s["recording"],
                "version": s["version"],
                **it,
            })

df_rec = pd.DataFrame(recording_rows)
df_items = pd.DataFrame(item_rows)
print(f"{len(df_rec)} recordings, {len(df_items)} items total")
df_rec.head()
# Out:
# 205 recordings, 8481 items total
#          recording    version  item_count  empty_count  mean_word_prob  \
# 0  038.068_EITv-1A  version_a          43            0          0.7965
# 1  038.069_EITv-2A  version_a          38            0          0.9318
# 2  038.070_EITv-1A  version_a          37            0          0.9202
# 3   038.071_EITv2A  version_a          37            0          0.9407
# 4   038.072_EITv1A  version_a          38            0          0.9229
#
#    mean_duration
# 0          5.760
# 1          4.921
# 2          4.873
# 3          5.673
# 4          5.576

# %% [markdown]
# ## 1. Overall recording stats

# %%
cols = ["item_count", "empty_count", "mean_word_prob", "mean_duration"]
print("=== Overall ===")
display(df_rec[cols].describe().round(3))
print("\n=== By version ===")
display(df_rec.groupby("version")[cols].describe().round(3))
# Out:
# === Overall ===
#        item_count  empty_count  mean_word_prob  mean_duration
# count     205.000      205.000         205.000        205.000
# mean       41.371        0.083           0.851          6.028
# std        12.208        0.310           0.083          2.366
# min         1.000        0.000           0.595          3.654
# 25%        37.000        0.000           0.804          5.054
# 50%        38.000        0.000           0.860          5.515
# 75%        40.000        0.000           0.920          6.171
# max        75.000        2.000           0.977         26.957
# === By version ===
#           item_count                                              empty_count  \
#                count    mean     std  min   25%   50%   75%   max       count
# version
# version_a      102.0  40.441  10.794  1.0  37.0  38.0  40.0  72.0       102.0
# version_b      103.0  42.291  13.453  1.0  37.0  38.0  40.0  75.0       103.0
#
#                   ... mean_word_prob        mean_duration                \
#             mean  ...            75%    max         count   mean    std
# version           ...
# version_a  0.098  ...          0.923  0.973         102.0  6.249  2.402
# version_b  0.068  ...          0.910  0.977         103.0  5.809  2.321
#
#
#              min    25%    50%    75%     max
# version
# version_a  4.062  5.140  5.593  6.448  24.600
# version_b  3.654  4.944  5.472  6.092  26.957
#
# [2 rows x 32 columns]

# %% [markdown]
# ## 2. Language detection by item index
# Shows which language Whisper detected at each item position across all recordings.

# %%
lang_colors = {"en": "#4C72B0", "es": "#DD8452", "other": "#888888"}

df_items["language_grouped"] = df_items["language"].apply(
    lambda l: l if l in ("en", "es") else "other"
)

print("Overall language distribution:")
display(df_items["language_grouped"].value_counts().to_frame(name="item_count"))

lang_pivot = (
    df_items.groupby(["index", "language_grouped"])
    .size()
    .unstack(fill_value=0)
    .reindex(columns=["en", "es", "other"], fill_value=0)
)

fig, ax = plt.subplots(figsize=(16, 4))
lang_pivot.plot(kind="bar", stacked=True, ax=ax, width=0.85,
                color=[lang_colors[c] for c in lang_pivot.columns])
ax.set_title("Language detected per item index (stacked across all recordings)", fontsize=12)
ax.set_xlabel("Item index")
ax.set_ylabel("Number of recordings")
ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
ax.legend(title="Language", bbox_to_anchor=(1.01, 1), loc="upper left")
fig.tight_layout()
plt.savefig("../plots/language_by_index_short.png", dpi=150)
plt.show()
# Out:
# Overall language distribution:
#                   item_count
# language_grouped
# es                      5036
# en                      2539
# other                    906

# %%
suspicious = df_items[
    (df_items["language_grouped"] == "other") |
    ((df_items["language_grouped"] == "en") & (df_items["index"] > 7))
][["recording", "version", "index", "language", "language_probability", "text"]].sort_values(
    ["recording", "index"]
).reset_index(drop=True)

print(f"{len(suspicious)} suspicious item(s) across {suspicious['recording'].nunique()} recording(s):\n")
pd.set_option("display.max_rows", None)
display(suspicious)
pd.reset_option("display.max_rows")
# Out:
# 2002 suspicious item(s) across 187 recording(s):
#                 recording    version  index language  language_probability  \
# 0         038.068_EITv-1A  version_a     10       en                0.3342
# 1         038.068_EITv-1A  version_a     11       pt                0.8398
# 2         038.068_EITv-1A  version_a     12       en                0.3796
# 3         038.068_EITv-1A  version_a     13       fr                0.6782
# 4         038.068_EITv-1A  version_a     20       la                0.5205
# 5         038.068_EITv-1A  version_a     22       pt                0.4780
# 6         038.068_EITv-1A  version_a     23       la                0.8350
# 7         038.068_EITv-1A  version_a     26       pt                0.5415
# 8         038.068_EITv-1A  version_a     27       en                0.7290
# 9         038.068_EITv-1A  version_a     28       cs                0.4226
# 10        038.068_EITv-1A  version_a     29       la                0.7285
# 11        038.068_EITv-1A  version_a     31       en                0.8599
# 12        038.068_EITv-1A  version_a     34       en                0.3167
# 13        038.068_EITv-1A  version_a     35       la                0.7666
# 14        038.068_EITv-1A  version_a     36       la                0.9370
# 15        038.068_EITv-1A  version_a     37       pt                0.7651
# 16        038.068_EITv-1A  version_a     38       la                0.6968
# 17        038.068_EITv-1A  version_a     40       en                0.4453
# 18        038.068_EITv-1A  version_a     42       en                0.9995
# 19        038.068_EITv-1B  version_b      9       pt                0.2388
# 20        038.068_EITv-1B  version_b     11       en                0.4512
# 21        038.068_EITv-1B  version_b     12       en                0.1796
# 22        038.068_EITv-1B  version_b     13       en                0.4309
# 23        038.068_EITv-1B  version_b     17       da                0.4148
# 24        038.068_EITv-1B  version_b     18       la                0.2583
# 25        038.068_EITv-1B  version_b     19       la                0.3459
# 26        038.068_EITv-1B  version_b     20       la                0.3860
# 27        038.068_EITv-1B  version_b     21       en                0.3726
# 28        038.068_EITv-1B  version_b     23       en                0.6597
# 29        038.068_EITv-1B  version_b     24       la                0.8716
# 30        038.068_EITv-1B  version_b     25       la                0.4470
# 31        038.068_EITv-1B  version_b     26       en                0.7070
# 32        038.068_EITv-1B  version_b     27       la                0.5063
# 33        038.068_EITv-1B  version_b     32       pt                0.4199
# 34        038.068_EITv-1B  version_b     34       en                0.5449
# 35        038.068_EITv-1B  version_b     35       en                0.3398
# 36        038.068_EITv-1B  version_b     36       en                0.5010
# 37        038.069_EITv-1B  version_b     10       hr                0.3647
# 38        038.069_EITv-1B  version_b     16       bg                0.3804
# 39        038.069_EITv-1B  version_b     17       it                0.9478
# 40        038.069_EITv-1B  version_b     18       la                0.6255
# 41        038.069_EITv-1B  version_b     24       ru                0.2271
# 42        038.069_EITv-1B  version_b     26       ro                0.6553
# 43        038.069_EITv-1B  version_b     29       pt                0.9297
# 44        038.070_EITv-1A  version_a     11       de                0.4131
# 45        038.070_EITv-1A  version_a     34       he                0.5527
# 46        038.070_EITv-2B  version_b      9       de                0.9116
# 47        038.070_EITv-2B  version_b     12       el                0.3149
# 48        038.070_EITv-2B  version_b     18       la                0.5249
# 49         038.071_EITv1B  version_b     11       en                0.2025
# 50         038.071_EITv1B  version_b     37       en                0.5723
# 51         038.072_EITv1A  version_a     20       gl                0.5225
# 52         038.072_EITv1A  version_a     23       la                0.4717
# 53         038.072_EITv1A  version_a     35       it                0.3376
# 54         038.072_EITv2B  version_b     11       cy                0.9722
# 55         038.072_EITv2B  version_b     17       la                0.5259
# 56         038.072_EITv2B  version_b     19       la                0.7158
# 57         038.072_EITv2B  version_b     27       en                0.4939
# 58         038.072_EITv2B  version_b     33       el                0.8789
# 59         038.073_EITv1B  version_b      8       en                0.2563
# 60         038.073_EITv1B  version_b      9       sv                0.1255
# 61         038.073_EITv1B  version_b     22       la                0.5742
# 62         038.073_EITv1B  version_b     23       en                0.4070
# 63         038.073_EITv1B  version_b     26       ko                0.6138
# 64         038.073_EITv1B  version_b     29       la                0.5034
# 65         038.073_EITv1B  version_b     33       en                0.8677
# 66         038.073_EITv1B  version_b     35       en                0.9941
# 67         038.073_EITv2A  version_a     10       it                0.7827
# 68         038.073_EITv2A  version_a     12       la                0.8267
# 69         038.073_EITv2A  version_a     26       it                0.3242
# 70         038.073_EITv2A  version_a     29       la                0.3047
# 71         038.073_EITv2A  version_a     31       la                0.5229
# 72         038.073_EITv2A  version_a     34       la                0.3245
# 73        038.074_EITv-1A  version_a     12       en                0.4856
# 74        038.074_EITv-1A  version_a     14       it                0.8174
# 75        038.074_EITv-1A  version_a     18       de                0.2659
# 76        038.074_EITv-1A  version_a     21       la                0.4016
# 77        038.074_EITv-1A  version_a     25       pt                0.6777
# 78        038.074_EITv-1A  version_a     27       la                0.5088
# 79        038.074_EITv-1A  version_a     28       la                0.8232
# 80        038.074_EITv-1A  version_a     30       la                0.6699
# 81        038.074_EITv-1A  version_a     38       en                0.6479
# 82        038.074_EITv-2B  version_b      9       de                0.3572
# 83        038.074_EITv-2B  version_b     12       la                0.4333
# 84        038.074_EITv-2B  version_b     18       la                0.5459
# 85        038.074_EITv-2B  version_b     21       en                0.5166
# 86        038.074_EITv-2B  version_b     25       sl                0.5225
# 87        038.074_EITv-2B  version_b     33       en                0.3855
# 88        038.074_EITv-2B  version_b     37       en                0.3948
# 89        038.075_EITv-2A  version_a      2       de                0.2563
# 90        038.075_EITv-2A  version_a      8       en                0.9888
# 91        038.076_EITv-1A  version_a     11       fr                0.3000
# 92        038.076_EITv-1A  version_a     32       en                0.6182
# 93        038.076_EITv-2B  version_b      8       en                0.5454
# 94        038.076_EITv-2B  version_b     19       la                0.4490
# 95        038.076_EITv-2B  version_b     20       ro                0.5532
# 96        038.077_EITv-1B  version_b      8       et                0.3997
# 97        038.077_EITv-1B  version_b      9       sq                0.4126
# 98        038.077_EITv-1B  version_b     17       la                0.9419
# 99        038.077_EITv-1B  version_b     18       en                0.4629
# 100       038.077_EITv-1B  version_b     23       en                0.9141
# 101       038.077_EITv-1B  version_b     24       la                0.5996
# 102       038.077_EITv-1B  version_b     33       en                0.8486
# 103       038.077_EITv-2A  version_a     14       it                0.8398
# 104       038.077_EITv-2A  version_a     19       la                0.7808
# 105       038.077_EITv-2A  version_a     28       en                0.4199
# 106       038.077_EITv-2A  version_a     34       la                0.8481
# 107       038.078_EITv-1A  version_a      9       en                0.8242
# 108       038.078_EITv-1A  version_a     10       ro                0.3201
# 109       038.078_EITv-1A  version_a     14       en                0.4199
# 110       038.078_EITv-2B  version_b      8       en                0.5483
# 111       038.078_EITv-2B  version_b      9       hr                0.8335
# 112       038.078_EITv-2B  version_b     10       sq                0.7104
# 113       038.078_EITv-2B  version_b     17      haw                0.3662
# 114       038.079_EITv-1B  version_b     10       fi                0.1721
# 115       038.079_EITv-1B  version_b     16       en                0.4795
# 116       038.079_EITv-1B  version_b     18       la                0.4265
# 117       038.079_EITv-2A  version_a      8       en                0.9785
# 118       038.080_EITv-1A  version_a     10       en                0.3442
# 119       038.080_EITv-1A  version_a     11       la                0.7466
# 120       038.080_EITv-1A  version_a     12       la                0.4282
# 121       038.080_EITv-1A  version_a     14       en                0.5698
# 122       038.080_EITv-1A  version_a     15       la                0.4131
# 123       038.080_EITv-1A  version_a     16       la                0.6494
# 124       038.080_EITv-1A  version_a     17       la                0.7842
# 125       038.080_EITv-1A  version_a     18       en                0.8486
# 126       038.080_EITv-1A  version_a     19       la                0.9448
# 127       038.080_EITv-1A  version_a     23       en                0.8096
# 128       038.080_EITv-1A  version_a     25       la                0.8359
# 129       038.080_EITv-1A  version_a     26       en                0.3149
# 130       038.080_EITv-1A  version_a     27       la                0.9507
# 131       038.080_EITv-1A  version_a     28       en                0.6191
# 132       038.080_EITv-1A  version_a     29       la                0.7485
# 133       038.080_EITv-1A  version_a     30       la                0.4917
# 134       038.080_EITv-1A  version_a     33       la                0.5972
# 135       038.080_EITv-1A  version_a     37       en                0.9883
# 136       038.080_EITv-2B  version_b      8       en                0.3911
# 137       038.080_EITv-2B  version_b      9       cy                0.3584
# 138       038.080_EITv-2B  version_b     10       la                0.4468
# 139       038.080_EITv-2B  version_b     11       la                0.6689
# 140       038.080_EITv-2B  version_b     17       la                0.8994
# 141       038.080_EITv-2B  version_b     19       la                0.8545
# 142       038.080_EITv-2B  version_b     21       en                0.5859
# 143       038.080_EITv-2B  version_b     22       en                0.9521
# 144       038.080_EITv-2B  version_b     23       ms                0.8940
# 145       038.080_EITv-2B  version_b     30       la                0.8745
# 146       038.080_EITv-2B  version_b     31       la                0.5176
# 147       038.080_EITv-2B  version_b     32       en                0.5767
# 148       038.080_EITv-2B  version_b     35       en                0.2866
# 149       038.080_EITv-2B  version_b     37       en                0.9492
# 150       038.081_EITv-1B  version_b     12       en                0.4470
# 151       038.081_EITv-1B  version_b     38       en                0.9966
# 152       038.081_EITv-2A  version_a     20       la                0.9556
# 153       038.082_EIT1_vA  version_a      8       en                0.9834
# 154       038.082_EIT1_vA  version_a      9       en                0.8579
# 155       038.082_EIT1_vA  version_a     12       en                0.7788
# 156       038.082_EIT1_vA  version_a     25       en                0.3806
# 157       038.082_EIT1_vA  version_a     29       en                0.3374
# 158       038.082_EIT1_vA  version_a     31       en                0.4214
# 159       038.082_EIT1_vA  version_a     35       en                0.7236
# 160       038.082_EIT1_vA  version_a     37       ko                0.7788
# 161       038.082_EIT1_vA  version_a     41       en                0.4805
# 162       038.082_EIT1_vA  version_a     43       en                0.7241
# 163       038.082_EIT1_vA  version_a     46       ko                0.1725
# 164       038.082_EIT1_vA  version_a     50       pt                0.5356
# 165       038.082_EIT1_vA  version_a     51       en                0.7236
# 166       038.082_EIT1_vA  version_a     53       en                0.4180
# 167       038.082_EIT1_vA  version_a     58       en                0.9775
# 168       038.082_EIT2_vB  version_b      8       en                0.9370
# 169       038.082_EIT2_vB  version_b      9       en                0.9922
# 170       038.082_EIT2_vB  version_b     10       en                0.7983
# 171       038.082_EIT2_vB  version_b     11       en                0.9937
# 172       038.082_EIT2_vB  version_b     12       en                0.7651
# 173       038.082_EIT2_vB  version_b     13       en                0.5298
# 174       038.082_EIT2_vB  version_b     17       en                0.7109
# 175       038.082_EIT2_vB  version_b     18       en                0.4980
# 176       038.082_EIT2_vB  version_b     19       en                0.5322
# 177       038.082_EIT2_vB  version_b     20       la                0.3755
# 178       038.082_EIT2_vB  version_b     22       en                0.6265
# 179       038.082_EIT2_vB  version_b     28       en                0.2122
# 180       038.082_EIT2_vB  version_b     33       en                0.6284
# 181       038.082_EIT2_vB  version_b     36       en                0.2859
# 182       038.082_EIT2_vB  version_b     38       en                0.4866
# 183       038.082_EIT2_vB  version_b     40       la                0.4993
# 184       038.082_EIT2_vB  version_b     46       en                0.3701
# 185       038.082_EIT2_vB  version_b     48       ko                0.3960
# 186       038.082_EIT2_vB  version_b     52       cy                0.8833
# 187       038.082_EIT2_vB  version_b     54       en                0.8999
# 188       038.082_EIT2_vB  version_b     56       en                0.4648
# 189       038.082_EIT2_vB  version_b     58       en                0.9209
# 190       038.082_EIT2_vB  version_b     60       en                0.4956
# 191       038.082_EIT2_vB  version_b     62       en                0.4456
# 192       038.082_EIT2_vB  version_b     63       en                0.8027
# 193       038.083_EITv-1B  version_b      8       fi                0.6558
# 194       038.083_EITv-1B  version_b     11       en                0.8364
# 195       038.083_EITv-1B  version_b     12       ro                0.6445
# 196       038.083_EITv-1B  version_b     13       lv                0.6250
# 197       038.083_EITv-1B  version_b     17       it                0.4429
# 198       038.083_EITv-1B  version_b     18       sl                0.4832
# 199       038.083_EITv-1B  version_b     20       la                0.2815
# 200       038.083_EITv-1B  version_b     24       sk                0.7046
# 201       038.083_EITv-1B  version_b     33       fi                0.7104
# 202       038.083_EITv-2A  version_a      8       it                0.2235
# 203       038.083_EITv-2A  version_a     11       la                0.3533
# 204       038.083_EITv-2A  version_a     13       la                0.8525
# 205       038.083_EITv-2A  version_a     27       la                0.7202
# 206       038.083_EITv-2A  version_a     36       la                0.5278
# 207       038.084_EIT1_vA  version_a     46       en                0.4854
# 208       038.084_EIT2_vB  version_b      8       en                0.9487
# 209       038.084_EIT2_vB  version_b      9       en                0.9795
# 210       038.084_EIT2_vB  version_b     10       en                0.9692
# 211       038.084_EIT2_vB  version_b     11       en                0.9731
# 212       038.084_EIT2_vB  version_b     12       en                0.8384
# 213       038.084_EIT2_vB  version_b     13       en                0.6035
# 214       038.084_EIT2_vB  version_b     59       en                0.9878
# 215       038.084_EIT2_vB  version_b     70       en                0.6777
# 216       038.085_EIT1_vB  version_b      8       en                0.9922
# 217       038.085_EIT1_vB  version_b      9       en                0.7861
# 218       038.085_EIT1_vB  version_b     10       en                0.9854
# 219       038.085_EIT1_vB  version_b     11       en                0.8286
# 220       038.085_EIT1_vB  version_b     13       en                0.8862
# 221       038.085_EIT1_vB  version_b     14       en                0.5986
# 222       038.085_EIT1_vB  version_b     15       en                0.8809
# 223       038.085_EIT1_vB  version_b     16       nl                0.7754
# 224       038.085_EIT1_vB  version_b     18       en                0.5693
# 225       038.085_EIT1_vB  version_b     21       en                0.7515
# 226       038.085_EIT1_vB  version_b     24       en                0.4941
# 227       038.085_EIT1_vB  version_b     26       en                0.9351
# 228       038.085_EIT1_vB  version_b     28       en                0.5229
# 229       038.085_EIT1_vB  version_b     32       en                0.9258
# 230       038.085_EIT1_vB  version_b     34       en                0.9272
# 231       038.085_EIT1_vB  version_b     36       en                0.7812
# 232       038.085_EIT1_vB  version_b     38       en                0.7803
# 233       038.085_EIT1_vB  version_b     40       en                0.9414
# 234       038.085_EIT1_vB  version_b     42       en                0.6396
# 235       038.085_EIT1_vB  version_b     44       en                0.9746
# 236       038.085_EIT1_vB  version_b     46       en                0.8643
# 237       038.085_EIT1_vB  version_b     50       en                0.5962
# 238       038.085_EIT1_vB  version_b     53       en                0.6782
# 239       038.085_EIT1_vB  version_b     59       en                0.7539
# 240       038.085_EIT2_vA  version_a      0       el                0.3738
# 241       038.085_EIT2_vA  version_a      8       en                0.9868
# 242       038.085_EIT2_vA  version_a      9       en                0.8647
# 243       038.085_EIT2_vA  version_a     11       en                0.3125
# 244       038.085_EIT2_vA  version_a     16       en                0.8652
# 245       038.085_EIT2_vA  version_a     18       en                0.4060
# 246       038.085_EIT2_vA  version_a     24       en                0.8384
# 247       038.085_EIT2_vA  version_a     25       en                0.8467
# 248       038.085_EIT2_vA  version_a     26       la                0.4670
# 249       038.085_EIT2_vA  version_a     28       en                0.7100
# 250       038.085_EIT2_vA  version_a     32       en                0.7266
# 251       038.085_EIT2_vA  version_a     34       en                0.9165
# 252       038.085_EIT2_vA  version_a     37       en                0.8452
# 253       038.085_EIT2_vA  version_a     41       en                0.9258
# 254       038.085_EIT2_vA  version_a     45       en                0.7339
# 255       038.085_EIT2_vA  version_a     47       ko                0.4097
# 256       038.085_EIT2_vA  version_a     49       en                0.8501
# 257       038.085_EIT2_vA  version_a     51       en                0.5586
# 258       038.085_EIT2_vA  version_a     53       en                0.6313
# 259       038.085_EIT2_vA  version_a     55       en                0.4216
# 260       038.085_EIT2_vA  version_a     57       en                0.8569
# 261       038.085_EIT2_vA  version_a     59       en                0.4231
# 262       038.085_EIT2_vA  version_a     60       en                0.9087
# 263       038.086_EIT1_vA  version_a     11       en                0.4524
# 264       038.086_EIT1_vA  version_a     14       la                0.6162
# 265       038.086_EIT1_vA  version_a     18       la                0.7446
# 266       038.086_EIT1_vA  version_a     19       en                0.4673
# 267       038.086_EIT1_vA  version_a     20       la                0.4661
# 268       038.086_EIT1_vA  version_a     24       en                0.5171
# 269       038.086_EIT1_vA  version_a     29       la                0.6431
# 270       038.086_EIT1_vA  version_a     31       la                0.4260
# 271       038.086_EIT1_vA  version_a     35       la                0.3228
# 272       038.086_EIT1_vA  version_a     37       en                0.4338
# 273       038.086_EIT1_vA  version_a     38       en                0.8931
# 274       038.086_EIT1_vA  version_a     39       pt                0.3850
# 275       038.086_EIT1_vA  version_a     42       en                0.9043
# 276       038.086_EIT1_vA  version_a     43       en                0.8638
# 277       038.086_EIT2_vB  version_b      8       en                0.9834
# 278       038.086_EIT2_vB  version_b      9       en                0.9307
# 279       038.086_EIT2_vB  version_b     10       en                0.9854
# 280       038.086_EIT2_vB  version_b     11       en                0.9214
# 281       038.086_EIT2_vB  version_b     12       en                0.9722
# 282       038.086_EIT2_vB  version_b     13       en                0.8789
# 283       038.086_EIT2_vB  version_b     14       en                0.6562
# 284       038.086_EIT2_vB  version_b     22       en                0.5610
# 285       038.086_EIT2_vB  version_b     25       la                0.9424
# 286       038.086_EIT2_vB  version_b     26       nn                0.2522
# 287       038.086_EIT2_vB  version_b     28       la                0.5879
# 288       038.086_EIT2_vB  version_b     32       la                0.3508
# 289       038.086_EIT2_vB  version_b     34       la                0.4470
# 290       038.086_EIT2_vB  version_b     35       en                0.3308
# 291       038.086_EIT2_vB  version_b     38       la                0.5776
# 292       038.086_EIT2_vB  version_b     40       la                0.7427
# 293       038.086_EIT2_vB  version_b     42       la                0.8926
# 294       038.086_EIT2_vB  version_b     44       la                0.2927
# 295       038.086_EIT2_vB  version_b     46       la                0.4990
# 296       038.086_EIT2_vB  version_b     48       la                0.3372
# 297       038.086_EIT2_vB  version_b     52       la                0.5503
# 298       038.086_EIT2_vB  version_b     56       la                0.5088
# 299       038.086_EIT2_vB  version_b     58       en                0.9688
# 300       038.087_EIT1_vB  version_b      8       en                0.9756
# 301       038.087_EIT1_vB  version_b      9       en                0.8618
# 302       038.087_EIT1_vB  version_b     60       tl                0.4143
# 303       038.087_EIT1_vB  version_b     65       en                0.9214
# 304   038.087_EIT1_vB (1)  version_b      8       en                0.9756
# 305   038.087_EIT1_vB (1)  version_b      9       en                0.8618
# 306   038.087_EIT1_vB (1)  version_b     60       tl                0.4143
# 307   038.087_EIT1_vB (1)  version_b     65       en                0.9214
# 308       038.087_EIT2_vA  version_a      8       en                0.9897
# 309       038.087_EIT2_vA  version_a      9       en                0.8794
# 310       038.087_EIT2_vA  version_a     59       en                0.9761
# 311       038.087_EIT2_vB  version_b      8       en                0.9897
# 312       038.087_EIT2_vB  version_b      9       en                0.8794
# 313       038.087_EIT2_vB  version_b     59       en                0.9761
# 314       038.088_EIT1_vA  version_a      8       en                0.9487
# 315       038.088_EIT1_vA  version_a      9       en                0.8140
# 316       038.088_EIT1_vA  version_a     11       en                0.6597
# 317       038.088_EIT1_vA  version_a     33       en                0.7183
# 318       038.088_EIT1_vA  version_a     37       en                0.4248
# 319       038.088_EIT1_vA  version_a     41       pt                0.5308
# 320       038.088_EIT1_vA  version_a     42       en                0.9097
# 321       038.088_EIT2_vB  version_b      8       en                0.9873
# 322       038.088_EIT2_vB  version_b      9       en                0.8540
# 323       038.088_EIT2_vB  version_b     10       en                0.9668
# 324       038.088_EIT2_vB  version_b     11       en                0.8354
# 325       038.088_EIT2_vB  version_b     12       en                0.6299
# 326       038.088_EIT2_vB  version_b     17       en                0.8159
# 327       038.088_EIT2_vB  version_b     19       ko                0.4011
# 328       038.088_EIT2_vB  version_b     23       pt                0.6606
# 329       038.088_EIT2_vB  version_b     27       id                0.7710
# 330       038.088_EIT2_vB  version_b     29       id                0.2449
# 331       038.088_EIT2_vB  version_b     35       pt                0.4966
# 332       038.088_EIT2_vB  version_b     41       ko                0.2155
# 333       038.088_EIT2_vB  version_b     46       tl                0.4492
# 334       038.088_EIT2_vB  version_b     50       en                0.3726
# 335       038.088_EIT2_vB  version_b     55       id                0.2279
# 336       038.088_EIT2_vB  version_b     56       en                0.2515
# 337       038.089_EITv-1B  version_b      9       fi                0.8003
# 338       038.089_EITv-1B  version_b     11       la                0.3672
# 339       038.089_EITv-1B  version_b     12       fi                0.4624
# 340       038.089_EITv-1B  version_b     39       en                0.9668
# 341       038.089_EITv-2A  version_a     26       la                0.3787
# 342       038.089_EITv-2A  version_a     27       el                0.2362
# 343       038.089_EITv-2A  version_a     28       fi                0.8984
# 344       038.090_EIT1_vA  version_a      8       en                0.8843
# 345       038.090_EIT1_vA  version_a      9       en                0.9883
# 346       038.090_EIT1_vA  version_a     10       en                0.8960
# 347       038.090_EIT1_vA  version_a     11       en                0.5264
# 348       038.090_EIT1_vA  version_a     13       en                0.5225
# 349       038.090_EIT1_vA  version_a     14       en                0.8477
# 350       038.090_EIT1_vA  version_a     17       en                0.3521
# 351       038.090_EIT1_vA  version_a     19       en                0.5391
# 352       038.090_EIT1_vA  version_a     23       en                0.3567
# 353       038.090_EIT1_vA  version_a     27       ko                0.3972
# 354       038.090_EIT1_vA  version_a     29       en                0.4812
# 355       038.090_EIT1_vA  version_a     31       en                0.6816
# 356       038.090_EIT1_vA  version_a     36       en                0.8423
# 357       038.090_EIT1_vA  version_a     37       en                0.5093
# 358       038.090_EIT1_vA  version_a     42       en                0.5576
# 359       038.090_EIT1_vA  version_a     45       en                0.6523
# 360       038.090_EIT1_vA  version_a     46       en                0.5581
# 361       038.090_EIT1_vA  version_a     50       en                0.3613
# 362       038.090_EIT1_vA  version_a     51       en                0.9009
# 363       038.090_EIT2_vB  version_b      8       en                0.9600
# 364       038.090_EIT2_vB  version_b      9       en                0.9512
# 365       038.090_EIT2_vB  version_b     10       en                0.9878
# 366       038.090_EIT2_vB  version_b     11       en                0.8608
# 367       038.090_EIT2_vB  version_b     12       en                0.9790
# 368       038.090_EIT2_vB  version_b     13       en                0.7720
# 369       038.090_EIT2_vB  version_b     16       en                0.7061
# 370       038.090_EIT2_vB  version_b     19       en                0.4280
# 371       038.090_EIT2_vB  version_b     21       en                0.3269
# 372       038.090_EIT2_vB  version_b     24       en                0.4331
# 373       038.090_EIT2_vB  version_b     29       en                0.2847
# 374       038.090_EIT2_vB  version_b     31       en                0.7549
# 375       038.090_EIT2_vB  version_b     33       en                0.6904
# 376       038.090_EIT2_vB  version_b     35       en                0.6807
# 377       038.090_EIT2_vB  version_b     37       en                0.5044
# 378       038.090_EIT2_vB  version_b     39       en                0.3789
# 379       038.090_EIT2_vB  version_b     41       en                0.4836
# 380       038.090_EIT2_vB  version_b     43       en                0.6675
# 381       038.090_EIT2_vB  version_b     45       en                0.7397
# 382       038.090_EIT2_vB  version_b     47       en                0.8804
# 383       038.090_EIT2_vB  version_b     51       en                0.5337
# 384       038.090_EIT2_vB  version_b     55       en                0.4226
# 385       038.090_EIT2_vB  version_b     58       ko                0.4062
# 386       038.090_EIT2_vB  version_b     60       en                0.4697
# 387       038.090_EIT2_vB  version_b     62       en                0.5010
# 388       038.090_EIT2_vB  version_b     64       en                0.7920
# 389       038.090_EIT2_vB  version_b     66       en                0.4758
# 390       038.090_EIT2_vB  version_b     67       en                0.5171
# 391       038.091_EITv-2A  version_a      7       el                0.8618
# 392       038.092_EITv-2B  version_b      8       fi                0.7842
# 393       038.092_EITv-2B  version_b     37       en                0.9258
# 394       038.093_EIT1_vB  version_b      8       en                0.9863
# 395       038.093_EIT1_vB  version_b      9       en                0.9038
# 396       038.093_EIT1_vB  version_b     10       en                0.9731
# 397       038.093_EIT1_vB  version_b     11       en                0.7910
# 398       038.093_EIT1_vB  version_b     16       en                0.7510
# 399       038.093_EIT1_vB  version_b     18       en                0.6177
# 400       038.093_EIT1_vB  version_b     22       en                0.7778
# 401       038.093_EIT1_vB  version_b     24       en                0.8911
# 402       038.093_EIT1_vB  version_b     27       en                0.4939
# 403       038.093_EIT1_vB  version_b     28       en                0.3669
# 404       038.093_EIT1_vB  version_b     30       en                0.8828
# 405       038.093_EIT1_vB  version_b     32       en                0.8389
# 406       038.093_EIT1_vB  version_b     34       la                0.5273
# 407       038.093_EIT1_vB  version_b     36       en                0.6880
# 408       038.093_EIT1_vB  version_b     38       en                0.8198
# 409       038.093_EIT1_vB  version_b     40       en                0.6094
# 410       038.093_EIT1_vB  version_b     42       en                0.8452
# 411       038.093_EIT1_vB  version_b     44       en                0.8286
# 412       038.093_EIT1_vB  version_b     46       en                0.6997
# 413       038.093_EIT1_vB  version_b     48       en                0.6714
# 414       038.093_EIT1_vB  version_b     50       en                0.7759
# 415       038.093_EIT1_vB  version_b     52       en                0.9443
# 416       038.093_EIT1_vB  version_b     54       en                0.8623
# 417       038.093_EIT1_vB  version_b     56       en                0.6289
# 418       038.093_EIT1_vB  version_b     58       en                0.5015
# 419       038.093_EIT1_vB  version_b     60       en                0.2815
# 420       038.093_EIT1_vB  version_b     62       en                0.7759
# 421       038.093_EIT1_vB  version_b     64       en                0.8955
# 422       038.093_EIT1_vB  version_b     65       en                0.9639
# 423       038.093_EIT2_vA  version_a      8       en                0.8750
# 424       038.093_EIT2_vA  version_a      9       en                0.9897
# 425       038.093_EIT2_vA  version_a     10       en                0.8975
# 426       038.093_EIT2_vA  version_a     14       ms                0.2446
# 427       038.093_EIT2_vA  version_a     16       en                0.3425
# 428       038.093_EIT2_vA  version_a     19       en                0.8633
# 429       038.093_EIT2_vA  version_a     21       en                0.2732
# 430       038.093_EIT2_vA  version_a     23       en                0.6328
# 431       038.093_EIT2_vA  version_a     26       en                0.7446
# 432       038.093_EIT2_vA  version_a     28       en                0.9541
# 433       038.093_EIT2_vA  version_a     29       en                0.6880
# 434       038.093_EIT2_vA  version_a     31       en                0.8403
# 435       038.093_EIT2_vA  version_a     33       en                0.3867
# 436       038.093_EIT2_vA  version_a     35       en                0.5688
# 437       038.093_EIT2_vA  version_a     37       en                0.6475
# 438       038.093_EIT2_vA  version_a     39       en                0.8872
# 439       038.093_EIT2_vA  version_a     41       en                0.5679
# 440       038.093_EIT2_vA  version_a     47       en                0.7842
# 441       038.093_EIT2_vA  version_a     49       en                0.4714
# 442       038.093_EIT2_vA  version_a     51       en                0.8442
# 443       038.093_EIT2_vA  version_a     53       en                0.9316
# 444       038.093_EIT2_vA  version_a     55       en                0.8916
# 445       038.093_EIT2_vA  version_a     57       en                0.8994
# 446       038.093_EIT2_vA  version_a     59       en                0.8535
# 447       038.093_EIT2_vA  version_a     61       en                0.3030
# 448       038.093_EIT2_vA  version_a     62       en                0.8408
# 449       038.094_EITv-1A  version_a     11       it                0.7617
# 450       038.094_EITv-1A  version_a     26       en                0.4890
# 451       038.094_EITv-1A  version_a     38       en                0.9858
# 452       038.094_EITv-2B  version_b     16       en                0.4678
# 453       038.094_EITv-2B  version_b     18       en                0.2771
# 454       038.094_EITv-2B  version_b     24       sv                0.4077
# 455       038.094_EITv-2B  version_b     35       en                0.3572
# 456       038.095_EIT1_vB  version_b      8       en                0.9272
# 457       038.095_EIT1_vB  version_b      9       en                0.9707
# 458       038.095_EIT1_vB  version_b     10       en                0.9326
# 459       038.095_EIT1_vB  version_b     11       en                0.9619
# 460       038.095_EIT1_vB  version_b     12       en                0.8022
# 461       038.095_EIT1_vB  version_b     13       en                0.6587
# 462       038.095_EIT1_vB  version_b     16       ko                0.5176
# 463       038.095_EIT1_vB  version_b     19       en                0.5737
# 464       038.095_EIT1_vB  version_b     24       en                0.5649
# 465       038.095_EIT1_vB  version_b     28       en                0.3679
# 466       038.095_EIT1_vB  version_b     30       en                0.7114
# 467       038.095_EIT1_vB  version_b     32       en                0.4282
# 468       038.095_EIT1_vB  version_b     34       en                0.4402
# 469       038.095_EIT1_vB  version_b     36       en                0.6050
# 470       038.095_EIT1_vB  version_b     38       en                0.9375
# 471       038.095_EIT1_vB  version_b     42       en                0.3489
# 472       038.095_EIT1_vB  version_b     44       en                0.5161
# 473       038.095_EIT1_vB  version_b     47       en                0.8613
# 474       038.095_EIT1_vB  version_b     57       en                0.3989
# 475       038.095_EIT1_vB  version_b     59       en                0.9219
# 476       038.095_EIT2_vA  version_a      8       en                0.9785
# 477       038.095_EIT2_vA  version_a      9       en                0.8906
# 478       038.095_EIT2_vA  version_a     19       la                0.5342
# 479       038.095_EIT2_vA  version_a     26       ko                0.2062
# 480       038.095_EIT2_vA  version_a     31       en                0.2866
# 481       038.095_EIT2_vA  version_a     33       en                0.4854
# 482       038.095_EIT2_vA  version_a     36       la                0.5674
# 483       038.095_EIT2_vA  version_a     38       la                0.5806
# 484       038.095_EIT2_vA  version_a     48       en                0.3545
# 485       038.095_EIT2_vA  version_a     50       ko                0.5156
# 486       038.095_EIT2_vA  version_a     56       en                0.5366
# 487       038.095_EIT2_vA  version_a     59       en                0.9067
# 488       038.096_EIT1_vA  version_a      7       it                0.6138
# 489       038.096_EIT1_vA  version_a     24       tl                0.2749
# 490       038.096_EIT1_vA  version_a     29       ko                0.5815
# 491       038.096_EIT1_vA  version_a     35       it                0.3315
# 492       038.096_EIT1_vA  version_a     44       en                0.3311
# 493       038.096_EIT1_vA  version_a     47       en                0.5664
# 494       038.096_EIT2_vB  version_b      8       en                0.9302
# 495       038.096_EIT2_vB  version_b      9       en                0.9917
# 496       038.096_EIT2_vB  version_b     10       en                0.8423
# 497       038.096_EIT2_vB  version_b     11       en                0.9766
# 498       038.096_EIT2_vB  version_b     12       en                0.7788
# 499       038.096_EIT2_vB  version_b     13       en                0.5532
# 500       038.096_EIT2_vB  version_b     23       en                0.5562
# 501       038.096_EIT2_vB  version_b     28       en                0.3579
# 502       038.096_EIT2_vB  version_b     30       tl                0.6909
# 503       038.096_EIT2_vB  version_b     32       en                0.3645
# 504       038.096_EIT2_vB  version_b     39       pt                0.8198
# 505       038.096_EIT2_vB  version_b     41       la                0.4985
# 506       038.096_EIT2_vB  version_b     58       it                0.4851
# 507       038.096_EIT2_vB  version_b     62       la                0.7588
# 508       038.096_EIT2_vB  version_b     65       en                0.8037
# 509       038.097_EIT1_vB  version_b      8       en                0.9370
# 510       038.097_EIT1_vB  version_b      9       en                0.9854
# 511       038.097_EIT1_vB  version_b     10       en                0.7915
# 512       038.097_EIT1_vB  version_b     11       en                0.9829
# 513       038.097_EIT1_vB  version_b     12       en                0.7959
# 514       038.097_EIT1_vB  version_b     13       en                0.5156
# 515       038.097_EIT1_vB  version_b     22       en                0.6631
# 516       038.097_EIT1_vB  version_b     24       en                0.3552
# 517       038.097_EIT1_vB  version_b     28       en                0.6304
# 518       038.097_EIT1_vB  version_b     31       en                0.4006
# 519       038.097_EIT1_vB  version_b     35       en                0.2178
# 520       038.097_EIT1_vB  version_b     37       tl                0.9155
# 521       038.097_EIT1_vB  version_b     39       en                0.4404
# 522       038.097_EIT1_vB  version_b     43       en                0.5718
# 523       038.097_EIT1_vB  version_b     45       en                0.8818
# 524       038.097_EIT1_vB  version_b     47       la                0.4507
# 525       038.097_EIT1_vB  version_b     49       pt                0.5747
# 526       038.097_EIT1_vB  version_b     57       en                0.4062
# 527       038.097_EIT1_vB  version_b     66       en                0.9585
# 528       038.097_EIT2_vA  version_a      8       en                0.9800
# 529       038.097_EIT2_vA  version_a      9       en                0.8911
# 530       038.097_EIT2_vA  version_a     16       en                0.3457
# 531       038.097_EIT2_vA  version_a     22       en                0.4263
# 532       038.097_EIT2_vA  version_a     24       la                0.5215
# 533       038.097_EIT2_vA  version_a     30       en                0.4688
# 534       038.097_EIT2_vA  version_a     33       en                0.6099
# 535       038.097_EIT2_vA  version_a     41       pt                0.3428
# 536       038.097_EIT2_vA  version_a     47       en                0.7671
# 537       038.097_EIT2_vA  version_a     49       en                0.5337
# 538       038.097_EIT2_vA  version_a     52       en                0.8584
# 539       038.098_EIT1_vA  version_a      0       el                0.7163
# 540       038.098_EIT1_vA  version_a      8       en                0.9438
# 541       038.098_EIT1_vA  version_a      9       en                0.9009
# 542       038.098_EIT1_vA  version_a     11       en                0.7437
# 543       038.098_EIT1_vA  version_a     15       en                0.4050
# 544       038.098_EIT1_vA  version_a     28       la                0.4028
# 545       038.098_EIT1_vA  version_a     31       en                0.3503
# 546       038.098_EIT1_vA  version_a     44       it                0.3374
# 547       038.098_EIT1_vA  version_a     52       en                0.8652
# 548       038.098_EIT2_vB  version_b      0       el                0.7568
# 549       038.098_EIT2_vB  version_b      8       en                0.9707
# 550       038.098_EIT2_vB  version_b      9       en                0.9038
# 551       038.098_EIT2_vB  version_b     10       en                0.9756
# 552       038.098_EIT2_vB  version_b     11       en                0.9019
# 553       038.098_EIT2_vB  version_b     12       en                0.5244
# 554       038.098_EIT2_vB  version_b     17       en                0.2625
# 555       038.098_EIT2_vB  version_b     19       en                0.8013
# 556       038.098_EIT2_vB  version_b     29       en                0.2937
# 557       038.098_EIT2_vB  version_b     31       pt                0.2659
# 558       038.098_EIT2_vB  version_b     35       tl                0.4270
# 559       038.098_EIT2_vB  version_b     40       en                0.4446
# 560       038.098_EIT2_vB  version_b     42       la                0.3347
# 561       038.098_EIT2_vB  version_b     47       de                0.3887
# 562       038.098_EIT2_vB  version_b     51       en                0.1332
# 563       038.098_EIT2_vB  version_b     53       en                0.6724
# 564       038.098_EIT2_vB  version_b     57       pt                0.1484
# 565       038.098_EIT2_vB  version_b     59       en                0.2494
# 566       038.098_EIT2_vB  version_b     63       la                0.2108
# 567       038.098_EIT2_vB  version_b     66       en                0.9214
# 568       038.099_EIT1_vB  version_b      8       en                0.9136
# 569       038.099_EIT1_vB  version_b      9       en                0.9888
# 570       038.099_EIT1_vB  version_b     10       en                0.8354
# 571       038.099_EIT1_vB  version_b     11       en                0.9961
# 572       038.099_EIT1_vB  version_b     12       en                0.7651
# 573       038.099_EIT1_vB  version_b     13       en                0.5918
# 574       038.099_EIT1_vB  version_b     20       en                0.3782
# 575       038.099_EIT1_vB  version_b     26       en                0.6147
# 576       038.099_EIT1_vB  version_b     32       ro                0.4136
# 577       038.099_EIT1_vB  version_b     34       en                0.6152
# 578       038.099_EIT1_vB  version_b     42       en                0.6328
# 579       038.099_EIT1_vB  version_b     44       hr                0.2827
# 580       038.099_EIT1_vB  version_b     45       en                0.6069
# 581       038.099_EIT1_vB  version_b     49       en                0.3367
# 582       038.099_EIT1_vB  version_b     53       en                0.9146
# 583       038.099_EIT1_vB  version_b     54       en                0.7168
# 584       038.099_EIT1_vB  version_b     58       en                0.8105
# 585       038.099_EIT1_vB  version_b     60       en                0.3679
# 586       038.099_EIT1_vB  version_b     64       hy                0.7437
# 587       038.099_EIT1_vB  version_b     66       tl                0.4624
# 588       038.099_EIT1_vB  version_b     68       en                0.5352
# 589       038.099_EIT1_vB  version_b     70       en                0.3435
# 590       038.099_EIT1_vB  version_b     71       en                0.8887
# 591       038.099_EIT1_vB  version_b     72       en                0.8818
# 592       038.099_EIT2_vA  version_a      8       en                0.9858
# 593       038.099_EIT2_vA  version_a      9       en                0.9019
# 594       038.099_EIT2_vA  version_a     11       en                0.5190
# 595       038.099_EIT2_vA  version_a     15       en                0.2759
# 596       038.099_EIT2_vA  version_a     16       en                0.7627
# 597       038.099_EIT2_vA  version_a     18       en                0.5664
# 598       038.099_EIT2_vA  version_a     20       en                0.3396
# 599       038.099_EIT2_vA  version_a     22       la                0.4841
# 600       038.099_EIT2_vA  version_a     24       pt                0.8394
# 601       038.099_EIT2_vA  version_a     26       en                0.8730
# 602       038.099_EIT2_vA  version_a     28       en                0.3960
# 603       038.099_EIT2_vA  version_a     30       en                0.5249
# 604       038.099_EIT2_vA  version_a     32       en                0.4607
# 605       038.099_EIT2_vA  version_a     40       en                0.9053
# 606       038.099_EIT2_vA  version_a     45       en                0.5186
# 607       038.099_EIT2_vA  version_a     47       en                0.3149
# 608       038.099_EIT2_vA  version_a     49       fo                0.1636
# 609       038.099_EIT2_vA  version_a     54       en                0.3245
# 610       038.099_EIT2_vA  version_a     56       en                0.6162
# 611       038.099_EIT2_vA  version_a     58       ro                0.6050
# 612       038.099_EIT2_vA  version_a     59       en                0.9424
# ...
# 1727                             Kei diho akabar de oi?
# 1728                      Tu vu sepem ablar in portges.
# 1729            La chica che es bailo, bailo es cilena.
# 1730               Antes de comer lo hizo en la mañana.
# 1731                         De gusto a comer la mitia.
# 1732             Era mia contribare al capital de mios.
# 1733   Los números de personas que votar es incremento.
# 1734          En dis desalier elkaas jy waar das ka is.
# 1735                          You want me to stop this?
# 1736                          Era o sedutor cada manhã.
# 1737            Me gustan las películas que ganan bien.
# 1738               El chico que no lo sab sayo es bien.
# 1739             Despues de comer, estoy muy tranquilo.
# 1740                                         Thank you.
# 1741           Me gustaria caor presas castaria elvaea.
# 1742          Me gustaría que empezar color más pronto.
# 1743       Despues de llegar a la casa, comen el cielo.
# 1744                     que era la policia era famoso.
# 1745               Le pide un amigo que carie el carro.
# 1746                     l'examen ne fut tant difficile
# 1747                         libro che sta in la messa.
# 1748  Ai mucha gente che non toma nada para il desmu...
# 1749                              και ρόκο ήταν μετέδο.
# 1750                  Eia terminare pintare su patumta.
# 1751    El nino che si imbrogliò il gatto, esta triste.
# 1752       L'esame non fu così difficile come ho avuto.
# 1753   Ai muce entece no tamao nara appareil desu, iun.
# 1754                        Ok, så står han nå så løft.
# 1755                                Latere latine kāla.
# 1756                      Que eu dou o que acabar hoje.
# 1757                        I want to learn Portuguese.
# 1758               Հանդես դեկորեր մեկում է ուն մանցանը։
# 1759        Cruising the kayak displays via literature.
# 1760           Hva bygg kan jes aga jo, gjen er fri jo.
# 1761                                          and heavy
# 1762                                 Okay, Pessoa Sala.
# 1763                         I tell it, continue. Kata.
# 1764                                   Ke kabele la'oi.
# 1765                        La Casa Pasada, El Tugando.
# 1766                I guess it's the way I like to eat.
# 1767                         I want to thank my family.
# 1768                         Eos Acanta Libros. Acanta.
# 1769                                        prokustá...
# 1770                                           Augusta.
# 1771  I'm going to go back and eat the Frisco. My Frio.
# 1772                                 Het is best een...
# 1773                                 The Prima Accanto.
# 1774                       So, capi, capa ho, ful, fui.
# 1775                   So this is done with repetition.
# 1776                               El Libro's Talamesa.
# 1777                      A callow, a tellow, a pillow.
# 1778                      I'll switch it up to my menu.
# 1779        To those who thought of coming to Delaware.
# 1780  Saya suka membuat... membuat... membuat... mem...
# 1781                   That's been the Spurs us the nah
# 1782                            Was it Niccolo El Kido?
# 1783                   The grandness of these buildings
# 1784                                   El Niño, El Gato
# 1785                                   El Gato El Negro
# 1786                                  Elcantae personas
# 1787                                   accanto in linea
# 1788  It wasn't when I took the headphones out. Awes...
# 1789  Did it finish the whole thing? It said that wa...
# 1790  Looks like it only got through part of it. Let...
# 1791                                Obeisistan Nasalah.
# 1792              La chica con quė io bailo est Xilena.
# 1793            El jefe de catechalum pleado era gordo.
# 1794                               Yn pethau sy'n ysai.
# 1795                                 Latara Tienekerle.
# 1796                            Hugo Pradé, Portuguese.
# 1797             me gostala komeda, ki je sva ljudeble.
# 1798                   La chica che io bailo es cinena.
# 1799                               البيبال سلمتا سرفريو
# 1800          La princesa che era bonita, fu alla casa.
# 1801         Antes de sedere mi casa, busque mis gafas.
# 1802                                     El Hempi Breda
# 1803                            VPD med märmördarkassa.
# 1804                             Eller blå starnemessa.
# 1805                    И това е това, което има Петро.
# 1806                      e il seduce che ha la maniera
# 1807          Las calles de esta ciudad son muy anchas.
# 1808  Hiedet en neum of casa, quando vivem mis anima...
# 1809                               viestes marvellosas.
# 1810                          Cruza alla terza e si va.
# 1811                        A pintar o seu apartamento.
# 1812                                             vicino
# 1813                                    krear en pødøs.
# 1814                        Che ducest tu, Giversaroid?
# 1815                      Depois de sonhar, vou dormir.
# 1816         Chiedo una casa en que vivan mis animales.
# 1817                                    De mi-e fesina.
# 1818  I said it was done with the repetition. It was...
# 1819                          El Paisa esta en la sala.
# 1820                          Kev och Kev är där och...
# 1821            La chica con la peor blanca es chileno.
# 1822                                      نبدأ بالتحضير
# 1823        I asked my brother to help me in the house.
# 1824       Hay muchas personas que llevan el calcacino.
# 1825                              El pez is in la sala.
# 1826                          La tierra la tiene Carla.
# 1827                La chica con el caballo es chelena.
# 1828                             Me gustaria de comida.
# 1829  Meg gustaria kei esti semester terminant prontum.
# 1830            il bebè che è al momento si è assefrito
# 1831                 I asked my sister to take me home.
# 1832        A támogatás. Nem lehet egyszerű. Nem tudom.
# 1833                           A libro está en la mesa.
# 1834                       Do lo que sepa manejar bien.
# 1835                     El chico que salgo es español.
# 1836                       After teaching, I went to...
# 1837              Chiaro ne case che viva lus animalis.
# 1838                                           No, sir.
# 1839                                    Kriza na drečo.
# 1840                                    No brave equal.
# 1841                       Eg har pynta syrepartimenta.
# 1842         Me gustaria empezar las galore muy pronto.
# 1843     El niño piensa el morio de gato es muy triste.
# 1844          Un'amiga mia nos cuidar nos ninos, no se.
# 1845    El gata, que fue negro, se perseguía del perro.
# 1846          despues de terminar el empezar tu cuarto.
# 1847                                           No, sir.
# 1848  Despes det tar meg... ...jeg gatt om lønnen av...
# 1849                                   Kestän lemeistä.
# 1850    There are many people who don't have breakfast.
# 1851                 El chico con Dios algo es español.
# 1852    El niño a que se murió el gato está muy triste.
# 1853    El ladron che attrappa alla policia era famoso.
# 1854  Thank you for warning me about that, because t...
# 1855           Las casas de estas pais son muy grandes.
# 1856                   La chica che io bailo es cilena.
# 1857        Quiero un coche en que yo quepa mi familia.
# 1858            Una amiga mia me bailar con mis amigos.
# 1859         Antes de salir mi casa, buscar mis llaves.
# 1860                  Te portaria mi cafe in la cosina.
# 1861                                   Keiho akaber oe.
# 1862              che era un coccicchio e mia famiglia.
# 1863                                               more
# 1864  Antes de se leere med kasse buskeme is byrje a...
# 1865  That made me feel like I'm really bad at Spani...
# 1866                                 Um, we're gonna...
# 1867               Crusse alla dreccia, i sigue todo...
# 1868                      Eu penso assim na nossa alma.
# 1869                              S in women, la tarde.
# 1870     Okay, you keep a bye. Oh, okay, he's your boy.
# 1871                                A total Portuguese.
# 1872                   Antes de correr, quiere manzana.
# 1873                                      Estee Lauder.
# 1874                                       Gosei lagae.
# 1875                                     Unheimliche...
# 1876                                        Antes de...
# 1877                                        Oh, hippie.
# 1878                         The work is not that easy.
# 1879                                            Mm-hmm.
# 1880                                  Yeah, just music.
# 1881                              Htjel' kutar mi pelo.
# 1882                           Eu saluto a cara amanhã.
# 1883                              Eu digo que eu salvo.
# 1884                                      uso la reggia
# 1885                     I hope we'll see y'all in a...
# 1886                 La examen no fora difícil, pero...
# 1887                           I'm standing on my side.
# 1888                              A libro a style mesa.
# 1889             Oh, call it caught a note in a payload
# 1890                             El seduce cada mañana.
# 1891                               Kei tisu ke vasa oe.
# 1892                           Tu rukes sakar muy bien.
# 1893                       Las callas... mmm... no say.
# 1894                               Pode levar semana...
# 1895                   Las casas son muy bonitas caras.
# 1896   Me gustas las películas, um, something muy bien.
# 1897                       El Chico es algo en Espanol.
# 1898                   This place is in your tranquilo.
# 1899              Chiarum casa che vivent con animalis.
# 1900                                    I know so close
# 1901                                 A.S.O. Non-Simple.
# 1902                    I would like to hunt something.
# 1903                                 Cruces al derecho.
# 1904                Æg er að pýnta hér svo apartamento.
# 1905             El niño se miró su gata es muy triste.
# 1906               Un nino tiene cuidado. Es mi vicino.
# 1907                                  El gato es negro.
# 1908                                         y el perro
# 1909  Antes de poner salir, um, something en el cuarto.
# 1910  Despois de la mar la casa, uh, despois, no, so...
# 1911                       Ella, ella, poner es famosa.
# 1912                     I'll put it something so today
# 1913  I'll examine the font for it on, um, Dice, no,...
# 1914                     Oh gosh. Something in La Mesa.
# 1915  That was a lot harder than I expected. That's ...
# 1916                             El Pais is in La Sala.
# 1917                           La terea la tiene Carla.
# 1918                     I'll see you in the afternoon.
# 1919                              Chiero chere papu oe.
# 1920                    Doodle is safe, put up, put us.
# 1921            The houses in the country are very big.
# 1922                        Los Cochos son muy fuertes.
# 1923                   Me gusta la comida es saludable.
# 1924               La chica es que bailando es chileno.
# 1925                    Chiere un coche che mi familia.
# 1926      I also like to listen to books about romance.
# 1927                        something me Tia that's all
# 1928                       cruiskaya a la despois de la
# 1929                  El entre en la paz de los amigos.
# 1930                A bebe se lobe, timante e sta frio.
# 1931                La princesa la fuimos a la cantaba.
# 1932            de la cantidad de personas de criminal.
# 1933                               ანთეს წებოსკერ მოსევ
# 1934                            I'll put it in La Casa.
# 1935         The house was not made with what was said.
# 1936                 something in the cafe a la cocina.
# 1937  I go to the house because it's new. It takes a...
# 1938             Jeg vil passe i stedet, at jeg sidder.
# 1939                           La tarea la tiene Carla.
# 1940                           Eu seguir-me pela tarde?
# 1941                                    K'iwaka bar'oi.
# 1942                 Tuvo que sepan a hablar portugués.
# 1943                A garota que eu bailo está chilena?
# 1944           Chiero un coche in que quepa mi familia.
# 1945         El bebe, que se cayó la manta, tiene frío.
# 1946                   Ela vai ter que ampliar o gordo.
# 1947               Can Taya make coffee in the kitchen?
# 1948                            Chiero cotarmi al pelo.
# 1949                           A libro está en la mesa.
# 1950         Las calles de esta ciudad son muy lanches.
# 1951      Chiero una casa en que la viven mis animales.
# 1952  A nosotros nos facían las fiestas grandes, los...
# 1953     El niño de que se murió el gato es muy triste.
# 1954                           Chiero comerme el huevo.
# 1955                               Yl pes ystân masala.
# 1956                                         acabar oe.
# 1957            Las casas de esta pais son muy grandes.
# 1958              Los coches son muy baratos pero feos.
# 1959           La chica con quien yo baile est chilena.
# 1960            Antes de correr me comieron la manzana.
# 1961            Me gusta que el hijo de mi tia comiera.
# 1962          Krosi la ca e, despoj sva jo a la dereca.
# 1963                           El entre con tus amigos.
# 1964      Me gustaría que la semestre terminara pronto.
# 1965  El bebés que se mantas tiene frío. Mantiene frío.
# 1966  Me pidiera a mia mana me ayuda me lim... in la...
# 1967            Las caes de esta ciudad son moi anchas.
# 1968          Ne gustam las peliculas, que acaban bien.
# 1969     Chiarum una casa in la che vivam mis animalis.
# 1970    A nosotros nos fascinan las fiestas grandiosas.
# 1971         Cier una casa in laque vivan mis animales.
# 1972    Una amiga mia cuidato los vecinos de mi vecina.
# 1973                                      Let that air.
# 1974                     Eu sei do chequear amanhã, né?
# 1975                           KĒ DISAJ UZTEIS BĀZĒROJ?
# 1976              Antes de salir, limpiarmi in quattro.
# 1977                                         Thank you.
# 1978                                         Thank you.
# 1979                                      Be a natural.
# 1980                            Eu penso estar na sala.
# 1981                           La terre la tiena calda.
# 1982                           Tu duermas por la tarde.
# 1983                             K'i dihi'l dek'bar'oi?
# 1984              Antes de correr, me comi una manzana.
# 1985                 Kira un koche kei para mi familia.
# 1986                Cruz Lacalle displays a la derecha.
# 1987        El bebe que se cayó al manto tiene el frio.
# 1988         La cantidad de los fontos ha incrementado.
# 1989           Antes de salir a casa busque mis llaves.
# 1990         I asked my sister to help me in the house.
# 1991               Te importeria el café ena kosenería.
# 1992                              O livro está na mesa.
# 1993                              Y caro nô tîn e pêlô.
# 1994          Can you say who's taking the bus, Airway?
# 1995              Lus caeste estas iudats vimui anchas.
# 1996                  Poi diceva la manana e il giorno.
# 1997  A nosotros les gustan las fiestas muy grandiosas.
# 1998               Ela só bebe cerveja e não come nada.
# 1999          Una amiga mia cuida los ninos del vecino.
# 2000             This place they sell their El Trabajo.
# 2001     The drone that captured the police was famous.

# %% [markdown]
# ## 3. Word-level confidence distribution

# %%
colors = {"version_a": "#4C72B0", "version_b": "#DD8452"}

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

# Per-item mean confidence histogram
ax = axes[0]
for ver in VERSIONS:
    sub = df_items[df_items["version"] == ver]["mean_word_prob"].dropna()
    ax.hist(sub, bins=20, alpha=0.6, label=ver, color=colors[ver], edgecolor="white")
ax.set_title("Per-item mean word confidence", fontsize=12)
ax.set_xlabel("Mean word probability")
ax.set_ylabel("Item count")
ax.legend()

# Per-recording mean confidence
ax = axes[1]
for ver in VERSIONS:
    sub = df_rec[df_rec["version"] == ver]["mean_word_prob"]
    ax.hist(sub, bins=20, alpha=0.6, label=ver, color=colors[ver], edgecolor="white")
ax.set_title("Per-recording mean word confidence", fontsize=12)
ax.set_xlabel("Mean word probability")
ax.set_ylabel("Recording count")
ax.legend()

fig.tight_layout()
plt.savefig("../plots/confidence_distribution_short.png", dpi=150)
plt.show()

# %% [markdown]
# ## 4. Empty transcripts

# %%
empty_items = df_items[df_items["empty"]]
print(f"{len(empty_items)} empty items across {empty_items['recording'].nunique()} recordings\n")

print("Empty items by index:")
display(empty_items["index"].value_counts().sort_index().to_frame())

print("\nRecordings with most empty items:")
display(
    df_rec[df_rec["empty_count"] > 0][["recording", "version", "item_count", "empty_count"]]
    .sort_values("empty_count", ascending=False)
    .reset_index(drop=True)
)
# Out:
# 17 empty items across 15 recordings
#
# Empty items by index:
#        count
# index
# 6          1
# 11         1
# 14         1
# 18         2
# 19         2
# 23         1
# 24         1
# 26         1
# 27         1
# 29         1
# 31         1
# 34         1
# 35         1
# 37         1
# 71         1
# Recordings with most empty items:
#           recording    version  item_count  empty_count
# 0   038.105_EIT2_vA  version_a          37            2
# 1     038036_EIT-1B  version_b          35            2
# 2   038.102_EIT1_vA  version_a          49            1
# 3     038014_EIT-2A  version_a          37            1
# 4     038018_EIT-2A  version_a          39            1
# 5     038025_EIT-1A  version_a          38            1
# 6     038012_EIT-2A  version_a          72            1
# 7     038029_EIT-1A  version_a          43            1
# 8    038029_EITv_1A  version_a          43            1
# 9    038.072_EITv2B  version_b          38            1
# 10    038036_EIT-2A  version_a          37            1
# 11  038.088_EIT2_vB  version_b          61            1
# 12  038.096_EIT2_vB  version_b          66            1
# 13    038006_EIT-1B  version_b          37            1
# 14    038014_EIT-1B  version_b          39            1

# %% [markdown]
# ## 5. Anomalies — recordings with unexpected item counts

# %%
mean_items = df_rec["item_count"].mean()
std_items = df_rec["item_count"].std()
threshold = mean_items - 2 * std_items

anomalies = df_rec[df_rec["item_count"] < threshold]
print(f"Mean item count: {mean_items:.1f}  |  Threshold (mean − 2σ): {threshold:.1f}")
print(f"{len(anomalies)} anomalous recording(s):")
display(anomalies[["recording", "version", "item_count", "empty_count"]].reset_index(drop=True))
# Out:
# Mean item count: 41.4  |  Threshold (mean − 2σ): 17.0
# 6 anomalous recording(s):
#         recording    version  item_count  empty_count
# 0  038063_EITv-2A  version_a          13            0
# 1  038066_EITv-1A  version_a           1            0
# 2  038test_EITvA1  version_a           2            0
# 3  038039_EITv-2B  version_b           1            0
# 4  038065_EITv-1B  version_b          10            0
# 5  038test_EITvB2  version_b           7            0

# %% [markdown]
# ## 6. Sample transcripts — first few items of one recording

# %%
SAMPLE_RECORDING = df_rec.iloc[0]["recording"]
SAMPLE_VERSION = df_rec.iloc[0]["version"]

sample = df_items[(df_items["recording"] == SAMPLE_RECORDING) & (df_items["version"] == SAMPLE_VERSION)]
print(f"First 10 items of {SAMPLE_RECORDING} ({SAMPLE_VERSION}):\n")
for _, row in sample.head(10).iterrows():
    print(f"  [{row['index']:2d}] lang={row['language']} ({row['language_probability']:.2f})  "
          f"words={row['word_count']}  conf={row['mean_word_prob']}")
    print(f"       {row['text'][:120]}")
# Out:
# First 10 items of 038.068_EITv-1A (version_a):
#
#   [ 0] lang=en (1.00)  words=98  conf=0.8954
#        I think this one's still going. Oh, shoot. Sorry. That's all good. Go back to the beginning. Okay. Okay. Is it stopped y
#   [ 1] lang=en (0.96)  words=2  conf=0.3637
#        Oh yeah.
#   [ 2] lang=en (0.99)  words=5  conf=0.9674
#        We drove to the park.
#   [ 3] lang=en (1.00)  words=5  conf=0.9971
#        I'll call her tomorrow night.
#   [ 4] lang=en (0.99)  words=8  conf=0.9635
#        You can buy meat at the butcher shop.
#   [ 5] lang=en (0.97)  words=8  conf=0.9704
#        My brother just bought a brand new computer.
#   [ 6] lang=en (0.99)  words=11  conf=0.9818
#        Sometimes they take their dog for a walk in the park.
#   [ 7] lang=en (0.98)  words=13  conf=0.9884
#        We're going to play volleyball at the gym that I told you about.
#   [ 8] lang=es (0.87)  words=4  conf=0.9856
#        Quiero cortarme el pelo.
#   [ 9] lang=es (0.61)  words=6  conf=0.9871
#        El libro está en la mesa.
